# %%
from density_based_anomalies_detetions import *

# %%
import seaborn as sns 
from sklearn.datasets import make_blobs


X, y = make_blobs(n_samples=100, centers=2, n_features=2)
sns.scatterplot (x= X[:,0],y = X[:,1],hue = y)

# %%
## add anomaly 
X = np.append (X, np.array([[2.5,-3]]),axis=0)
y = np.append (y, np.array([1]),axis=0)

# %%
sns.scatterplot (x= X[:,0],y = X[:,1],hue = y)

# %%
result = compute_scores (X,X)

# %%
sns.lineplot (range(len(result)),result)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
## see the correspondant maxima 

anomalies_indexes= result.argsort()[-10:]

# %%
##change label of these points 
for i in anomalies_indexes : 
    y[i] = 2

# %%
sns.scatterplot (x= X[:,0],y = X[:,1],hue = y)
